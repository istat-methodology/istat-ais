# %%
from azureml.core import Workspace, Datastore, Dataset

# %%
ws = Workspace.from_config()

# %%
ais_datastore = Datastore.get(ws,datastore_name="aisdatastore")

# %%
dataset_obj = Dataset.get_by_name(ws, "data_csv", version="latest")

# %%
df=dataset_obj.to_pandas_dataframe()

# %%
df.head()
# Out:
#                DATAFLOW         LAST UPDATE freq indic_de geo  TIME_PERIOD  \
# 0  ESTAT:DEMO_GIND(1.0) 2022-04-04 23:00:00    A      AVG  AD         1986
# 1  ESTAT:DEMO_GIND(1.0) 2022-04-04 23:00:00    A      AVG  AD         1987
# 2  ESTAT:DEMO_GIND(1.0) 2022-04-04 23:00:00    A      AVG  AD         1988
# 3  ESTAT:DEMO_GIND(1.0) 2022-04-04 23:00:00    A      AVG  AD         1989
# 4  ESTAT:DEMO_GIND(1.0) 2022-04-04 23:00:00    A      AVG  AD         1990
#
#    OBS_VALUE OBS_FLAG
# 0    45785.0     None
# 1    47714.0     None
# 2    49490.0     None
# 3    50708.0     None
# 4    52697.0     None
